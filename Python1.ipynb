# %% [markdown]
# # 1. Version de python

# %%
# !python --version
# Out:
# Python 3.7.11

# %% [markdown]
# # 2. Calcul

# %%
38 + 4
# Out:
# 42

# %% [markdown]
# # 3. Formule mathématique en Markdown

# %% [markdown]
# $x= \frac{-b\pm\sqrt{b^2-4ac}}{2a}$

# %% [markdown]
# <iframe width="560" height="315"
# src="https://www.youtube.com/embed/videoseries?list=PLx0sYbCqOb8TBPRdmBHs5Iftvv9TPboYG"
# frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# # 4. Afficher vidéo Youtube

# %% [markdown]
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=inN8seMm7UI
# " target="_blank"><img src="http://img.youtube.com/vi/inN8seMm7UI/0.jpg"
# alt="IMAGE ALT TEXT HERE" width="240" height="180" border="0" /></a>
