# %%
test_list = [0, 3, -6, 9, 12, -15, 18, -21, 24, 27]

# %%
# Une fonction qui convertit des montants en dollars vers des montants en euros (prends le cours euro/dollar du jour où tu fais la quête).

def dollar_to_euro(price):
  return price * 0.86

dollar_to_euro(12)
# Out:
# 10.32

# %%
(lambda x: x*0.86)(12)
# Out:
# 10.32

# %%
# Une fonction qui renvoie la somme des nombres pairs présents dans une liste contenant des nombres entiers.

def somme_pairs(liste):
  result = 0
  for i in liste:
    if i %2 == 0:
      result += i
  return result

somme_pairs(test_list)
# Out:
# 48

# %%
result = [i + i for i in test_list if i%2 == 0][-1]
result
# Out:
# 48

# %%
#Un script qui convertit une liste de nombres entiers positifs ou négatifs) en une nouvelle liste contenant les valeurs absolues.

def val_abs(liste):
  new_list = []
  for i in liste:
    if i < 0:
      new_list.append(-i)
    else:
      new_list.append(i)
  return new_list

val_abs(test_list)
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
abs_val = lambda x : [abs(i) for i in x ]
abs_val(test_list)
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27]
